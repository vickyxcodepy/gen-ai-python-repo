# %%
a = int(input("enter number"))
b = int(input("enter number"))
c = int(input("enter number"))

if a > b:
    if a > c:
        print(a,"number a is greater than number b and c",b,c)
    else:
        print(c,"c is largest number")
else:
    if b > c:
        print(b"number b is greater")
    else:
        print(c,"number c is greatest")
# Out:
# 30 number c is greatest
