# %% [markdown]
# ## python assesment : 1

# %% [markdown]
# #### 1. Create a variable x with value 10 and a variable y with value 20. Print their sum.

# %%
x = 10
y = 20
print(x+y)
# Out:
# 30

# %% [markdown]
# #### Assign your name to a variable name and print "Hello, <name>".

# %%
x = "vignesh"
print("hello",x)
# Out:
# hello vignesh

# %% [markdown]
# #### Swap two variables a = 5 and b = 10 without using a third variable.

# %%
a =5
b = 10
a,b=b,a
print(b)
print(a)
# Out:
# 5
# 10

# %% [markdown]
# #### Take user input for age and print "You are <age> years old".

# %%
age = int(input());
print("you are",age,"years old")
# Out:
# you are 10 years old

# %% [markdown]
# #### Write a Python program to check if a number is even r odd using the modulus operator.

# %%
x = 10
if x%2 == 0:
    print("even")

else:
    print("odd")
# Out:
# even

# %% [markdown]
# #### If a = 15 and b = 4, find the sum, difference, product, division, and modulus.

# %%
a = 15 
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 19
# 11
# 60
# 3.75
# 3

# %% [markdown]
# #### Write a Python program that checks if a number is positive, negative, or zero.

# %%
x = int(input())
if x > 0:
    print("positive")
elif x < 0:
    print("negative")
else:
    print("zero")
# Out:
# positive
